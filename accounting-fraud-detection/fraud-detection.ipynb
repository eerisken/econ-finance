# %%
# !pip install lazypredict --use-feature=2020-resolver --user
# Out:
# Requirement already satisfied: lazypredict in c:\users\eeris\appdata\roaming\python\python37\site-packages (0.2.9)
# Requirement already satisfied: joblib==1.0.0 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: pytest==5.4.3 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: pandas==1.0.5 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: tqdm==4.56.0 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: xgboost==1.1.1 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: six==1.15.0 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: click==7.1.2 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: PyYAML==5.3.1 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: scikit-learn==0.23.1 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: lightgbm==2.3.1 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: numpy==1.19.1 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: scipy==1.5.4 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (8.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.3.0)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.1.8)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.5.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from pytest==5.4.3->lazypredict) (19.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.1)
# Requirement already satisfied: py>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.8.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\eeris\appdata\roaming\python\python37\site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (2.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.6)
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lick (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\eeris\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\eeris\appdata\roaming\python\python37\site-packages)

# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\eeris\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df = pd.read_csv(r"fraud_dataset_uscecchini28.csv")

# %%
df.tail()
# Out:
#         fyear   gvkey    sich  insbnk  understatement  option  p_aaer  \
# 146040   2014  314866 8200.00       0               0       0     nan
# 146041   2014  315318 2890.00       0               0       0     nan
# 146042   2014  316056 3420.00       0               0       0     nan
# 146043   2014  317260 4412.00       0               0       0     nan
# 146044   2014  317264 4412.00       0               0       0     nan
#
#         new_p_aaer  misstate     act  ...  soft_assets  ch_cs  ch_cm  ch_roa  \
# 146040         nan         0  262.60  ...         0.75   0.56   0.13   -0.05
# 146041         nan         0 1578.40  ...         0.74  -0.12   0.03    0.10
# 146042         nan         0  973.80  ...         0.75   0.00  -0.04    0.07
# 146043         nan         0   51.74  ...         0.02    nan    nan     nan
# 146044         nan         0  233.21  ...         0.07   1.68  -0.09    0.02
#
#         issue    bm  dpi  reoa  EBIT  ch_fcf
# 146040      1  0.10 0.83 -0.33 -0.01   -0.26
# 146041      1  0.58 0.74 -0.08  0.00   -0.30
# 146042      1 -0.00 1.06 -0.00  0.15    0.07
# 146043      1  1.11  nan  0.00  0.03     nan
# 146044      1  1.15 0.75  0.03  0.03   -0.24
#
# [5 rows x 51 columns]

# %%
y = df['misstate']
X = df.drop('misstate', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
X.head()
# Out:
#    fyear  gvkey    sich  insbnk  understatement  option  p_aaer  new_p_aaer  \
# 0   1990   1009 3460.00       0               0       0     nan         nan
# 1   1990   1011 4841.00       0               0       0     nan         nan
# 2   1990   1017 3812.00       0               0       0     nan         nan
# 3   1990   1021 3861.00       0               0       0     nan         nan
# 4   1990   1028 7385.00       0               0       0     nan         nan
#
#     act   ap  ...  soft_assets  ch_cs  ch_cm  ch_roa  issue    bm  dpi  reoa  \
# 0 10.05 3.74  ...         0.31   0.10   0.08   -0.02      1  0.41 0.87  0.17
# 1  1.25 0.80  ...         0.32   0.19  -0.21   -0.12      1  0.16 0.75 -0.43
# 2 55.04 3.60  ...         0.61   0.10  -0.11    0.09      1  2.23 1.02  0.39
# 3 24.68 3.95  ...         0.79  -0.01  -0.25    0.02      1  1.04 1.03  0.09
# 4 17.32 3.52  ...         0.87  -0.23  -1.67   -0.47      0 -1.60 0.60 -0.94
#
#    EBIT  ch_fcf
# 0  0.16   -0.04
# 1 -0.16    0.10
# 2  0.06    0.07
# 3  0.09   -0.02
# 4 -0.70    0.13
#
# [5 rows x 50 columns]

# %%
sum(y_test), len(X_test)
# Out:
# (195, 29209)

# %%
# fit all models
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [23:32<00:00, 48.71s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# GaussianNB                         0.99               0.99     0.99      0.99
# LGBMClassifier                     1.00               0.99     0.99      1.00
# QuadraticDiscriminantAnalysis      0.99               0.99     0.99      0.99
# ExtraTreesClassifier               1.00               0.99     0.99      1.00
# ExtraTreeClassifier                1.00               0.95     0.95      1.00
# KNeighborsClassifier               1.00               0.94     0.94      1.00
# SVC                                1.00               0.92     0.92      1.00
# BernoulliNB                        0.88               0.76     0.76      0.93
# PassiveAggressiveClassifier        0.98               0.75     0.75      0.99
# Perceptron                         0.99               0.70     0.70      0.99
# SGDClassifier                      0.99               0.62     0.62      0.99
# NearestCentroid                    0.99               0.58     0.58      0.99
# LinearDiscriminantAnalysis         0.99               0.58     0.58      0.99
# LogisticRegression                 0.99               0.57     0.57      0.99
# CalibratedClassifierCV             0.99               0.57     0.57      0.99
# RidgeClassifier                    0.99               0.57     0.57      0.99
# RidgeClassifierCV                  0.99               0.57     0.57      0.99
# LinearSVC                          0.99               0.57     0.57      0.99
# DummyClassifier                    0.99               0.50     0.50      0.99
#
#                                Time Taken
# Model
# AdaBoostClassifier                  34.11
# XGBClassifier                        6.75
# RandomForestClassifier              35.75
# DecisionTreeClassifier               1.56
# BaggingClassifier                    8.83
# GaussianNB                           0.74
# LGBMClassifier                       1.91
# QuadraticDiscriminantAnalysis        1.37
# ExtraTreesClassifier                20.76
# ExtraTreeClassifier                  0.66
# KNeighborsClassifier               454.72
# SVC                                513.37
# BernoulliNB                          0.59
# PassiveAggressiveClassifier          0.67
# Perceptron                           0.85
# SGDClassifier                        1.67
# NearestCentroid                      0.52
# LinearDiscriminantAnalysis           1.82
# LogisticRegression                   2.33
# CalibratedClassifierCV             253.46
# RidgeClassifier                      0.64
# RidgeClassifierCV                    1.54
# LinearSVC                           65.78
# DummyClassifier                      0.46
